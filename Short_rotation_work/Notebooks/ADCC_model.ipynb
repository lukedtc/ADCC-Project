# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys

# %%
sys.path.append('/home/sabsr3/Rotations/ADCC/ADCC-Project')
import ADCC_model_utils
from ADCC_model_utils import ADCCModelUtils

# %%
params = {'k_on1': 1e5,
          'k_off': 1e-4,
          'q_on1': 6.5e-3,
          'q_off': 4.7e-3,
          't_0': 1.44e4,
          'T_01': 4.15e-16,
          'beta_on': 2e13,
          'beta_off': 1e-3,
          'fk_1': 1,
          'rho_T': 1e5,
          'rho_N': 2.2e5,
          'time_step': 0.000008,
          'mu': 10,
          'A_01': 1e-9,
          't_start': 0.00000001,
          't_end': 1}

# %%
model = ADCCModelUtils(params)

# %%
sol = model.solve_model()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_30968/2284793521.py in <module>
# ----> 1 sol = model.solve_model()
#
# ~/Rotations/ADCC/ADCC-Project/ADCC_model_utils.py in solve_model(self)
#     140             t_evals = np.array([t, t + float(self.time_step), t_dt], dtype=object)
#     141             t_span = [t, t_dt]
# --> 142             z = solve_ivp(self.macroscale_model, t_span, macroscale_ICs, args = (coeffs[0], coeffs[1]), method = 'Radau', t_eval = t_evals )
#     143             S_val = z.y[0][1]
#     144             C_val = z.y[1][1]
#
# ~/.local/lib/python3.8/site-packages/scipy/integrate/_ivp/ivp.py in solve_ivp(fun, t_span, y0, method, t_eval, dense_output, events, vectorized, args, **options)
#     540         method = METHODS[method]
#     541
# --> 542     solver = method(fun, t0, y0, tf, vectorized=vectorized, **options)
#     543
# ...

# %%
A = sol[0]
T = sol[1]
Tr = sol[2]
N = sol[3]
Nr = sol[4]
S = sol[5]
C = sol[6]
t = sol[7]

sns.set_theme()
plt.semilogx(t, S, label = 'S')
plt.semilogx(t, C, label = 'C')
plt.legend()
plt.show()

# %%
plt.semilogx(t, T, label = r'$T_r$')
plt.semilogx(t, Tr, label = r'$T_r^A$')
plt.semilogx(t, N, label = r'$N_r$')
plt.semilogx(t, Nr, label = r'$N_r^A$')
plt.legend(loc='best')
plt.show()
