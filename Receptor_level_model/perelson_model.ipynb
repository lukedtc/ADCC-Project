# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#params

S0 = 100
kon = 1e5
koff = 1e-4
K1 = 2
alpha = 0.5
K2 = alpha*K1
C = np.geomspace(0.01, 1e4, 1000)


beta = K1*C/(1+K1*C)
delta = beta*(1-beta)*K2*S0
m = S0*beta*((-1 + (1 + 4*delta)**0.5)/(2*delta))
M = S0*((1 + 2*delta - (1 + 4*delta)**0.5)/(4*delta))

# %%
plt.plot(C, m/S0, label='m')
plt.plot(C, M/S0, label='M')
plt.plot(C, (m+M)/S0, label='occupancy')
plt.legend(loc='best')
plt.xlabel('Concentration')
plt.xscale('log')
plt.show()
